# %%
import pandas as pd
import numpy as np


# csv 파일이되 데이터 구분을 '|' 로 해둔 파일입니다. sep 지정을 안 하면 읽을 수 없습니다.
df = pd.read_csv('/content/drive/MyDrive/오픈소스 SW/소상공인시장진흥공단_상가(상권)정보_충남_202212.csv')
# Out:
# <ipython-input-1-3544e8a5ec5f>:6: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/오픈소스 SW/소상공인시장진흥공단_상가(상권)정보_충남_202212.csv')

# %%
df
# Out:
#           상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0       24536268      대건모터스  NaN         D       소매       D23  자동차/자동차용품
# 1       23868715         무한  NaN         D       소매       D01    음/식료품소매
# 2       20218177      삽다리식당  NaN         Q       음식       Q01         한식
# 3       21684400  한윤희국어논술학원  NaN         R    학문/교육       R01  학원-보습교습입시
# 4       24644351       롯데리아  안서점         D       소매       D13    책/서적/도서
# ...          ...        ...  ...       ...      ...       ...        ...
# 125304  19077983       별별분식  NaN         Q       음식       Q04         분식
# 125305  19078178     디자인시크릿  NaN         D       소매       D16      화장품소매
# 125306  19078385       미미헤어  NaN         F    생활서비스       F01    이/미용/건강
# 125307  19078584       세리영어  NaN         R    학문/교육       R01  학원-보습교습입시
# 125308  19080381       면사무소  NaN         Q       음식       Q01         한식
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호      건물명  \
# ...

# %%
# 음식점 데이터만 쓸 겁니다
df = df.loc[df['상권업종대분류명'] == '음식']  

# 다음과 같은 칼럼만 있으면 됩니다
df = df[['상호명', '상권업종중분류명', '상권업종소분류명', '표준산업분류명', '행정동명', '위도', '경도']]

# 그 중에서도 흑석동과 상도1동만 쓸 겁니다.
df = df.loc[(df['행정동명'] == '흑석동') | (df['행정동명'] == '상도1동')]

# %%
# 칼럼명 단순화

df.columns = ['name',  # 상호명
              'cate_1',  # 중분류명
              'cate_2',  # 소분류명
              'cate_3',  # 표준산업분류명
              'dong',  # 행정동명
              'lon',  # 위도
              'lat'  # 경도
              ]

# %%
df['cate_mix'] = df['cate_1'] + df['cate_2'] +  df['cate_3']
df['cate_mix'] = df['cate_mix'].str.replace("/", " ")

# %%
# pip install sklearn 혹은 conda install sklearn으로 사이킷런을 미리 다운 받아주세요.

from sklearn.feature_extraction.text import CountVectorizer  # 피체 벡터화
from sklearn.metrics.pairwise import cosine_similarity  # 코사인 유사도


count_vect_category = CountVectorizer(min_df=0, ngram_range=(1,2))
place_category = count_vect_category.fit_transform(df) 
place_simi_cate = cosine_similarity(place_category, place_category) 
place_simi_cate_sorted_ind = place_simi_cate.argsort()[:, ::-1]

# %%
# !pip install cartopy
import cartopy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# https://pypi.python.org/pypi/libarchive
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
import libarchive
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
